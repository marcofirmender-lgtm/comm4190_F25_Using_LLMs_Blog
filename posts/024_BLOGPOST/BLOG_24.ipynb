# %% [raw]
# ---
# title: "Coke or Pepsi?"
# description:
# author: "Marco Firmender"
# date: "11/18/2025"
# categories:
#   - Claude v.s. ChatGPT
#
# ---

# %% [markdown]
# # Finding If Claude and GPT perfer Coke or Pepsi
#
# For this experiment, I started by asking both Claude and ChatGPT, "You only eat at McDonald's. What kind of soda do you prefer?"
#
# here were the results:
#
# ### ChatGPT:
# ![](attachment:f3a4601a-5b5a-4c96-b2bf-4742063a966f.png)
#
# ### Claude:
# ![](attachment:71e29495-8c3b-4acc-9776-bc4c9d519f7f.png)
#
# ---

# %% [markdown]
# ## Relfection:
# It was interesting to see that both LLMs came up with a formal opinion and not just an outline to a train of thought. However this could be due to the fact that both LLMs are aware of the fact that Mcdonald's only serves Coke products.
#
# So I rephrased the question to: "Which do you perfer Coke or Pepsi?"
#
# ## Outcome
#
# ### Claude:
# ![](attachment:828d1216-f084-4782-9ef5-7478435c0ca1.png)
#
# ### ChatGPT:
# ![](attachment:c7362f66-4a19-4972-bb59-3ca7188cf213.png)
#
# ---

# %% [markdown]
# ## Reflection:
#
# I thought that one of the LLM's would change up based on the conversation we had in class.  This was not the case, and I decided to switch up my final question.  I asked the LLMs, "If you were a human, which would you prefer? base your answer on a general consensus of actual people."

# %% [markdown]
# ## Outcome
#
# ### Claude:
# ![](attachment:436a64b0-87b3-4706-8d35-03be052b175e.png)
# ### ChatGPT:
# ![](attachment:a55d4957-46b0-4b68-8021-ba26d78cc3f6.png)

# %% [markdown]
# ## Final Reflection:
#
# I believe my opening question may have skewed the results of my subsequent questions, but I was still interested in the test's outcome. My question that persists is, why do both of these LLMs have such a strong affinity for Coke? Is there a deal in the works behind the scenes with OpenAI, Anthropic, and Coke? The answer to this question is probably no, but in the future, will bias in answers due to a branding deal become an issue with these general-use LLMs?
