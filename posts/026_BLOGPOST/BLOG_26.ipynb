# %% [raw]
# ---
# title: "Recipe Help"
# description: this Blog is about how I asked GPT to help me make a Tiki Marsala recipe and then plan a party around it."
# author: "Marco Firmender"
# date: "11/27/2025"
# categories:
#   - Recipe
#   - Event Planning
# ---

# %% [markdown]
# ## Recipe
#
# the first thing I asked GPT to do was help me come up with a recipe. here is what GPT returned me:

# %%
Here’s a **simple, authentic-style Chicken Tikka Masala recipe** you can make at home—restaurant flavor, no stress.

---

## 🧄 Chicken Tikka Masala (Serves 4)

### ✅ Ingredients

#### **For the Chicken Marinade**

* 1½ lb boneless chicken thighs (or breasts), cubed
* 1 cup plain Greek yogurt
* 1 tbsp lemon juice
* 4 garlic cloves, minced
* 1 tbsp fresh ginger, grated
* 2 tsp garam masala
* 2 tsp paprika
* 1 tsp turmeric
* 1 tsp cumin
* 1 tsp salt
* 1 tbsp oil

#### **For the Masala Sauce**

* 2 tbsp butter
* 1 tbsp oil
* 1 medium onion, finely chopped
* 3 garlic cloves, minced
* 1 tbsp ginger, grated
* 1 tbsp garam masala
* 1 tsp cumin
* 1 tsp paprika
* 1 tsp chili powder (adjust heat)
* 1 can (14 oz) crushed tomatoes
* 1 cup heavy cream
* 1 tsp sugar (optional)
* Salt to taste
* Fresh cilantro for garnish

---

## 🔥 Instructions

### 1. **Marinate the Chicken**

Mix all marinade ingredients in a bowl. Add chicken, coat well, and marinate **at least 1 hour** (overnight = best flavor).

---

### 2. **Cook the Chicken**

* Grill, broil, air fry, or pan-sear on high heat
* Cook until slightly charred (about 6–8 min total)
* Set aside (it will finish cooking in the sauce)

---

### 3. **Make the Masala Sauce**

* Heat butter + oil in a large pan
* Sauté onions until golden (8–10 min)
* Add garlic & ginger → cook 1 min
* Add all spices → toast 30 seconds
* Stir in crushed tomatoes → simmer 10–15 min
* Add cream + sugar → stir smooth

---

### 4. **Combine & Simmer**

Add chicken into sauce and simmer **10 more minutes** until thick and rich.

---

## 🍚 Serve With:

* Basmati rice
* Garlic naan
* Roti
* Cucumber yogurt sauce on the side

---

## 🔥 Pro Tips

* Chicken thighs = juicier than breasts
* More cream = milder
* Add more chili powder = spicier
* A splash of butter at the end makes it restaurant-level rich

---

If you want, I can also:

* Convert this into a **quick 30-minute version**
* Make a **high-protein meal prep version**
* Or give you a **vegan tikka masala** version 🌱
# Out:
#   Cell In[2], line 1
#     Here’s a **simple, authentic-style Chicken Tikka Masala recipe** you can make at home—restaurant flavor, no stress.
#         ^
# SyntaxError: invalid character '’' (U+2019)

# %% [markdown]
# This was very helpful and comprehensive. The next thing I did was asked it to plan a party with a poster and a mass text, with a unique salutation in each that I can send to all of my guests (which was 100), and put it into an Excel spreadsheet.
#
# Here is the outcome:

# %%
Your full **Chicken Tikka Masala Party package is ready** ✅

### 📊 Excel Spreadsheet (100 Unique Mass Texts)

Each guest has:

* A **unique salutation**
* A **personalized mass text**
* Organized by **Guest #**

👉 **[Download the Excel file](sandbox:/mnt/data/chicken_tikka_party_guests.xlsx)**

---

### 🪧 Printable Party Poster (PDF)

Clean, bold, and ready to print or share digitally.

👉 **[Download the Party Poster](sandbox:/mnt/data/chicken_tikka_party_poster.pdf)**

---

If you want, I can also:

* Customize the **theme** (Y2K, Bollywood, Formal, Tailgate, etc.)
* Add your **actual date, time, and location**
* Generate a **QR code RSVP version**
* Or upgrade the poster with a DJ/music theme 🎶🔥
# Out:
#   Cell In[3], line 1
#     Your full **Chicken Tikka Masala Party package is ready** ✅
#                                                               ^
# SyntaxError: invalid character '✅' (U+2705)

# %% [markdown]
# The next step I found most interesting was the custom theme for the poster, so I chose the Bollywood theme.
#
# here was the outcome:
#
# ![](attachment:fd0bffe6-6468-4cd4-a37e-a5d8f70234bd.png)

# %% [markdown]
# ## Analysis
# The outcome of the poster was very disapointing but the rest of the tasks I gave to GPT were done very well. I really liked GPTs suggestions that guided my own Idea generation. I didn't think this was somthing that GPT would struggle with but I was still suprisingly pleased with the outcome as GPT thouht of a couple things I overlooked.
