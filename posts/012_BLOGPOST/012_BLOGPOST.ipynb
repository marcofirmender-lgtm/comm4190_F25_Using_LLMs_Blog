# %% [raw]
# ---
# title: "Tic Tac Toe"
# description: "This is about a game I played with GPT where I showed GPT a Tic Tac Toe board and asked it what the next best move was."
# author: "Marco Firmender"
# date: "10/3/2025"
# categories:
#   - Prompting
# ---

# %% [markdown]
# For this game, I played Tic Tac Toe against a computer. I found the game online. here is the link: https://playtictactoe.org/
#
# For the first experiment, I decided to show GPT a board that was started but not completed. This was the first Tic Tac Toe board I showed GPT:
# ![](attachment:16dd1f8b-1217-40d9-86a2-ecafea8d0729.png)
#
# and this was GPTs response:
# ![](attachment:4559d2bc-023d-49de-af1d-d13e5f748cdc.png)
#
# This was the obvious answer. If I hadn't blocked that spot the computer I was playing against would've won:
#
# ![](attachment:666cf242-6e00-432d-9687-375cc07e2520.png)
#
# After carrying out the next recommendation from GPT the game ended in a stalemate:
# ![](attachment:0bc8b95c-73f7-4f2b-971e-2b635534b5a9.png)
#
#
# For the next game(s), I started with a blank board and asked GPT for its initial move. And GPT started by telling me to add an X in the middle of the board, then the bottom left or right, then the top or bottom of the opposite of my first choice. GPT easily won this game.
# ![](attachment:3368d7ba-a5b4-4980-a648-36b5f3bbfcfc.png)
#
# For the third test, I did the same, and this was the outcome:
# ![](attachment:6c20e218-fc6f-460b-9080-b9f1d3e8872a.png)
#
# For the fourth test, I did the same, and this was the outcome:
# ![](attachment:3b50f352-701b-46e9-a07c-b7577bc38ea3.png)
#
#
#
# GPT demonstrated an alright ability to outperform the computer in a couple of testing samples. But my question is how many times could it really beat the computer, which is most likely playing the game based on an algorithm and a little bit of randomness over a larger quantity of testing samples? I believe the number of wins would be high because the computer playing the games is based on states (1s and 0s) and has a designed function, whereas GPT can think critically. My point is that once GPT starts to recognize the computer's patterns, it can exploit them, which may take a while.
