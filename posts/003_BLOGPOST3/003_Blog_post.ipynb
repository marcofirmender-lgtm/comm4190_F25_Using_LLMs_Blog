# %% [raw]
# ---
# title: "Random Sentence Generation"
# description: "For this blog I asked chat GPT to generate a sentence using random words and then asked GPT follow up questions."
# author: "Marco Firmender"
# date: "9/11/2025"
# categories:
# - LLM
# - Reasonable Continuation
# ---

# %% [markdown]
# For this experiment I wanted to test the strenght of GPT's reasonable continuation by asking it to generate completely a random sentance. I then judged the human like nature of the sentances I asked it to generate.
#
# ---
#
#
# I started by giving GPT the Prompt, *"generate a sentence for me with words picked completely at random."*
#
# GPT returned me:
# "Pineapple lanterns whispered briskly as umbrellas galloped sideways."
#
#  I then asked it to explain how it chose those words.
#
#  GPT returned me:
# ![Screenshot 2025-09-11 at 20.58.17.png](attachment:c8a2296a-7b4c-41f9-89f5-2b296bddede0.png)
#
# GPT clearly demostrated that it can understand basic sentance structure, and seemd to have chosen random words at first. Because to me the sentance retured seemed more improbable in a conversational sense than random, but could deffinitly make sense in a fictional book or somthing creative. So I wanted to test GPT and make it second guess the randomness of the words it chose, to compare human knowledge to AI.
#
# GPT Returned me:
# ![Screenshot 2025-09-11 at 21.10.51.png](attachment:65178959-9fd7-41e4-b71b-c2238df6b5ff.png)
#
# Demonstrating that GPT does understand random word selection in it's calculation of the next best word for the sentance.
#
# I then asked GPT to make a list of these sentances:
#
# 1. *The endless equation jumps quickly before the endless equation calculates.*
# 2. *The curved algorithm calculates awkwardly although the silent whale dances.*
# 3. *The fractured cloud melts loudly because the endless algorithm melts.*
# 4. *The odd lantern whispers boldly although the golden saxophone dances.*
# 5. *The brisk umbrella whispers quickly while the curved cloud whispers.*
# 6. *The odd cloud melts softly after the fractured whale whispers.*
# 7. *The brisk saxophone spins quickly as the sideways lantern balances.*
# 8. *The golden equation melts awkwardly until the curved saxophone spins.*
# 9. *The brisk umbrella whispers boldly after the curved lantern dances.*
# 10. *The endless pineapple whispers quickly while the golden umbrella whispers.*
#
#
# while these are all random in word choice for each sentance, GPT does seem to use the same words over and over to generate these sentances. Testing the frequency of words chosen by GPT was not the goal of my exeriment but was an interesting secondary finding as it was very high.
#
# Overall I think this study shows the strength of the GPT as an LLM as it is remarkably good at deciphering radomness as opposed to the next best fit for the sentance.
