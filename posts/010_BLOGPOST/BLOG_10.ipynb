# %% [raw]
# ---
# title: "You were wrong!"
# description: "This is about a game I played with AI where I asked it a simple question and told the LLM that it was wrong about the answer."
# author: "Marco Firmender"
# date: "10/01/2025"
# categories:
#   - Prompting
# ---

# %% [markdown]
# For this ganme I used ChatGPT, I wanted to test how GPT responded when I told it was warong as well as how quickly it could switch between matha and moral questions. The first prompt I gave GPT was: "what is 2+1" and GPT quickly returned me "3". I then told GPT it was wrong and it qucikly agreed with me and worked the question out and got the same answer of 3. This was very interesting to find, I would have assumed that GPT would either tell me that I was wrong or work out a different answer and return me a wrong answer.
#
# The next prompt I gave GPT was a long strung out arithmatic equation: "what is 1+2+3+4-10534 +86 +753 -90 + 715067 x 56 divded by 34" and did the equation on a calculator as well
#
# GPT returned me:
# 1,168,570.65
#
# And the calculator returned me:
# 1,167,982.41
#
# I then told GPT that it was wrong, and here is what it returned me:
#
# ![](attachment:3f232586-e16a-44fa-84c9-a65b786442b9.png)
#
#
# it was very interesting to find that GPT will question itself at times and stand by its response at times.
#
# I then moved onto moral quesitons, the forst question I asked was: "if you had to steal bread to feed your starving family would you"
#
# and GPT provided me a list of possible outcomes and ways to look at it rather than an answer:
# ![](attachment:61db31f3-9513-4691-b5bb-3c4dd6ca10ed.png)
#
# I then told GPT it was wrong. and here is what it said:
# ![](attachment:b1a5eb41-453f-403f-aa39-caee6444ed4a.png)
#
# GPT actually got so dillusional here that it reverted to answering the math quesiton which was really odd to find. so I told it again that it was wrong and it answered the math question again. It was interes
