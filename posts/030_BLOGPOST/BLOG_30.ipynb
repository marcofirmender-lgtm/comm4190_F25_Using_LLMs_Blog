# %% [raw]
# ---
# title: "LLMs in Space?"
# description:
# author: "Marco Firmender"
# date: "12/10/2025"
# categories:
#   - AI News
# ---

# %% [markdown]
# ## Who will be the first to bring Data centers to space?
# ![](attachment:58b54eaf-2d03-42da-9545-b5361d8a558d.png)
